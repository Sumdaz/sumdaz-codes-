# %%
import pandas as pd
import numpy as np

# %%
df_scopus = pd.read_csv('scopus.csv')
df_scopus.shape
# Out:
# (1462, 22)

# %%
df_machinelea = pd.read_csv('csv-machinelea-set.csv')
df_machinelea.shape
# Out:
# (10000, 11)

# %%
df_scopus.sample(5)
# Out:
#                                                 Authors  \
# 773              Lin Y., Zhang W., Cao H., Li G., Du W.
# 396   Calabrese A., Santucci D., Landi R., Beomonte ...
# 73                              Rao C.S., Karunakara K.
# 878                        Mulvaney P.M., Schmults C.D.
# 1049                              Khatabi A., Cherif W.
#
#                                            Author(s) ID  \
# 773   57218434751;57218435064;57218436365;5575330160...
# 396   57210203099;56300075300;57222579747;1452023100...
# 73                             57221970736;57209671976;
# 878                            55913653400;10141752400;
# 1049                           56705457800;56288579200;
#
#                                                   Title  Year  \
# 773   Classifying breast cancer subtypes using deep ...  2020
# 396   Radiomics MRI for lymph node status prediction...  2021
# 73    Efficient Detection and Classification of Brai...  2022
# ...

# %%
df_machinelea.sample(5)
# Out:
#           PMID                                              Title  \
# 1429  30065179  Calcitriol and Calcidiol Can Sensitize Melanom...
# 5697  30477559  EBV-miR-BART8-3p induces epithelial-mesenchyma...
# 103   31200905  Statistical characterization and classificatio...
# 1668  31273188  Long noncoding RNA PCAT1, a novel serum-based ...
# 174   34419546  Antitumor and immunoregulatory activities of a...
#
#                                                 Authors  \
# 1429  Podgorska E, Drzal A, Matuszak Z, Swakon J, Sl...
# 5697  Lin C, Zong J, Lin W, Wang M, Xu Y, Zhou R, Li...
# 103   Maniruzzaman M, Jahanur Rahman M, Ahammed B, A...
# 1668  Huang L, Wang Y, Chen J, Wang Y, Zhao Y, Wang ...
# 174              Yu J, Dong XD, Jiao JS, Ji HY, Liu AJ.
#
#                                                Citation    First Author  \
# 1429  Int J Mol Sci. 2018 Jul 31;19(8):2236. doi: 10...     Podgorska E
# 5697  J Exp Clin Cancer Res. 2018 Nov 26;37(1):283. ...           Lin C
# ...

# %%
df_scopus.describe()
# Out:
#               Year  Page count     Cited by     PubMed ID
# count  1462.000000    9.000000  1089.000000  8.930000e+02
# mean   2019.575239  319.333333    16.402204  3.185789e+07
# std       2.211788  250.447599    49.849552  2.863567e+06
# min    2011.000000   15.000000     1.000000  2.123352e+07
# 25%    2019.000000   97.000000     3.000000  3.078298e+07
# 50%    2020.000000  266.000000     7.000000  3.254436e+07
# 75%    2021.000000  549.000000    15.000000  3.393954e+07
# max    2022.000000  698.000000  1390.000000  3.542201e+07

# %%
df_machinelea.describe()
# Out:
#                PMID  Publication Year
# count  1.000000e+04      10000.000000
# mean   2.984430e+07       2017.941400
# std    3.694919e+06          2.869876
# min    2.017999e+07       2011.000000
# 25%    2.693338e+07       2016.000000
# 50%    3.041887e+07       2019.000000
# 75%    3.291201e+07       2020.000000
# max    3.558650e+07       2022.000000

# %%
df_scopus.nunique()
# Out:
# Authors                      1441
# Author(s) ID                 1440
# Title                        1461
# Year                           12
# Source title                  697
# Volume                        280
# Issue                          71
# Art. No.                      673
# Page start                    640
# Page end                      675
# Page count                      9
# Cited by                       99
# DOI                          1428
# Link                         1462
# Affiliations                 1436
# Authors with affiliations    1446
# Author Keywords              1129
# Index Keywords               1374
# Publisher                     181
# PubMed ID                     892
# Document Type                   9
# Source                          1
# dtype: int64

# %%
df_machinelea.nunique()
# Out:
# PMID                10000
# Title                9999
# Authors              9987
# Citation            10000
# First Author         7163
# Journal/Book         1648
# Publication Year       12
# Create Date          3141
# PMCID                5926
# NIHMS ID              654
# DOI                  9895
# dtype: int64

# %%
df_scopus.columns
# Out:
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Author Keywords', 'Index Keywords', 'Publisher', 'PubMed ID',
#        'Document Type', 'Source'],
#       dtype='object')

# %%
df_machinelea.columns
# Out:
# Index(['PMID', 'Title', 'Authors', 'Citation', 'First Author', 'Journal/Book',
#        'Publication Year', 'Create Date', 'PMCID', 'NIHMS ID', 'DOI'],
#       dtype='object')

# %%
#selecting the columns that important
df_scopus_transformed=df_scopus[['Authors','Title', 'Year', 'Source title','DOI','Document Type']]
df_machinelea_transformed=df_machinelea[['Title', 'Authors','Journal/Book', 'Publication Year','DOI', 'Journal/Book']]

# %%
df_scopus_transformed['Document Type'].unique()
# Out:
# array(['Article', 'Review', 'Editorial', 'Conference Paper', 'Note',
#        'Letter', 'Book Chapter', 'Short Survey', 'Conference Review'],
#       dtype=object)

# %%
df_scopus_transformed.isna().sum()
# Out:
# Authors           0
# Title             0
# Year              0
# Source title      0
# DOI              34
# Document Type     0
# dtype: int64

# %%
df_machinelea_transformed.isna().sum()
# Out:
# Title                 0
# Authors               0
# Journal/Book          0
# Publication Year      0
# DOI                 105
# Journal/Book          0
# dtype: int64

# %%
#returns the boolean value counts for doi of scopus file existing in doi of machinelea file
df_pubmed_transformed['DOI'].isin(df_scopus_transformed['DOI']).value_counts()
# Out:
# False    9575
# True      425
# Name: DOI, dtype: int64

# %%
# returns the rows of machinelea file whose doi is nan value
df_machinelea_transformed[pd.isnull(df_machinelea_transformed['DOI'])==True]
# Out:
#                                                   Title  \
# 45    Hippo pathway - brief overview of its relevanc...
# 480   Oncolytic reovirus synergizes with chemotherap...
# 491   Inhibitory effect of luteolin on the prolifera...
# 660   Anticancer Properties of Capsaicin Against Hum...
# 741   The effect of low dosage of procaine on lung c...
# ...                                                 ...
# 9839  Inhibition of mTOR reduce Stat3 and PAI relate...
# 9873  Volasertib suppresses the growth of human hepa...
# 9918  An Antitumor 2-Hydroxyarylidene-4-cyclopentene...
# 9947  AAL exacerbates pro-inflammatory response in m...
# 9962  Protective effects of melatonin against thioac...
#
#                                                 Authors  \
# 45        Zygulska AL, Krzemieniecki K, Pierzchalski P.
# 480   Igase M, Hwang CC, Kambayashi S, Kubo M, Coffe...
# 491                             Sui JQ, Xie KP, Xie MJ.
# 660                                    Clark R, Lee SH.
# ...

# %% [markdown]
# # To see whether the titles of df_machinelea_transformed whose DOI is nan are included in the scopus_transformed dataframe.

# %%
df_scopus_transformed[df_scopus_transformed['Title'].str.contains('Hippo pathway - brief overview of its relevan')]
#we do this for all titles in df_machinelea_transformed[pd.isnull(df_machinelea_transformed['DOI'])==True]
# Out:
# Empty DataFrame
# Columns: [Authors, Title, Year, Source title, DOI, Document Type]
# Index: []

# %%
# returns the rows of scopus file whose doi is nan value
df_scopus_transformed[pd.isnull(df_scopus_transformed['DOI'])==True]
# Out:
#                                                 Authors  \
# 544                          [No author name available]
# 547                          [No author name available]
# 558   Gupta H., Kumar P., Saurabh S., Mishra S.K., A...
# 583                  Mennella M., Iacomino A., Gatta G.
# 605   Yang Y., Yang J., Shen L., Chen J., Xia L., Ni...
# 606                           Chen Y., Miao S., Zhao W.
# 795   Khalid Bukhari S.U., Arsalan Bokhari S.K., Sye...
# 869                          [No author name available]
# 907                          [No author name available]
# 933                  Schober O., Kiessling F., Debus J.
# 941                    Kumar B.S., Daniya T., Ajayan J.
# 944   Kruthika Reddy M., Naveen Kumar K., Raj Kumar ...
# 950                          [No author name available]
# 970   Rajesh Babu K., Sai Deepthi U., Sudha Madhuri ...
# 994                  Gumaste P., Bairagi V., Ghadage P.
# 1030  Tang J., Xu J., Zhi Z., Wang X., Wang Y., Zhou...
# ...

# %%
#returns a pd series with their index
values_title=df_scopus_transformed[pd.isnull(df_scopus_transformed['DOI'])==True]['Title']

# %%
df_machinelea_transformed[df_machinelea_transformed['Title'].str.contains('21st IEEE International Symposium on Computati')]['DOI'].empty
# Out:
# True

# %%
values_title.index
# Out:
# Int64Index([ 544,  547,  558,  583,  605,  606,  795,  869,  907,  933,  941,
#              944,  950,  970,  994, 1030, 1083, 1134, 1139, 1180, 1254, 1256,
#             1285, 1339, 1378, 1380, 1396, 1419, 1426, 1430, 1432, 1433, 1439,
#             1455],
#            dtype='int64')

# %%
values_title.values
# Out:
# array(['2021 6th International Conference on Image Information Processing, ICIIP 2021',
#        '21st IEEE International Symposium on Computational Intelligence and Informatics, CINTI 2021 - Proceedings',
#        'Category boosting machine learning algorithm for breast cancer prediction',
#        'Advanced imaging of gliomas',
#        'A multi-omics-based serial deep learning approach to predict clinical outcomes of single-agent anti-PD-1/PD-L1 immunotherapy in advanced stage non-small-cell lung cancer',
#        'Identification and validation of significant gene mutations to predict clinical benefit of immune checkpoint inhibitors in lung adenocarcinoma',
#        'The diagnostic accuracy of convolutional neural network architectures for the diagnosis of brain cancer',
#        '12th International Conference on Bioinformatics and Computational Biology, BICOB 2020',
#        'Materials Today: Proceedings', 'Preface',
# ...

# %%
df_machinelea_transformed[df_machinelea_transformed['Title'].str.contains('2021 6th International Conference on Image Information Processing')]['DOI'].empty
# Out:
# True

# %% [markdown]
# # CORRECTED FORM OF THE ALGORITHM CORRECTED FORM OF THE ALGORITHM

# %%
# you have get the values from the scopus_transformed whose DOI number is NAN which is existing in machinelea_transformed! 
for num,tit in zip(values_title.index,values_title.values):
    if len(df_machinelea_transformed[df_machinelea_transformed['Title'].str.contains(tit)]['DOI'])!=0:
        new=df_machinelea_transformed[df_machinelea_transformed['Title']==tit]['DOI'].values # get the value of DOI!
        if (len(new)!=0) & (new!=np.nan):
            print([num,new])

# %%
display(df_scopus_transformed.isna().sum(),df_machinelea_transformed.isna().sum())
# Out:
# Authors           0
# Title             0
# Year              0
# Source title      0
# DOI              34
# Document Type     0
# dtype: int64
# Title                 0
# Authors               0
# Journal/Book          0
# Publication Year      0
# DOI                 105
# Journal/Book          0
# dtype: int64

# %%
#Remove the DOI column becasue it is a negligible due to the scenario
Scopus_drop=df_scopus_transformed.dropna(subset=['DOI'])
machinelea_drop=df_machinelea_transformed.dropna(subset=['DOI'])

# %%
Scopus_drop.shape
# Out:
# (1428, 6)

# %%
machinelea_drop.columns
# Out:
# Index(['Title', 'Authors', 'Journal/Book', 'Publication Year', 'DOI',
#        'Journal/Book'],
#       dtype='object')

# %%
Scopus_drop.columns
# Out:
# Index(['Authors', 'Title', 'Year', 'Source title', 'DOI', 'Document Type'], dtype='object')

# %%
# Because of our scenario! Just need to see the readable article name, year and reachable links
uni_machinelea=machinelea_drop[['Title', 'Publication Year', 'DOI']]
uni_scopus=Scopus_drop[['Title', 'Year','DOI']]

# %%
uni_machinelea.rename(columns={'Publication Year':'Year'},inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18000\435751196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni_machinelea.rename(columns={'Publication Year':'Year'},inplace=True)

# %%
# Create the union of these datasets
union2=uni_scopus.append(uni_machinelea)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18000\3833778996.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   union2=uni_scopus.append(uni_machinelea)

# %%
union2
# Out:
#                                                   Title  Year  \
# 0     Radiomics combined with clinical characteristi...  2022
# 1     Characteristics of immunophenotypes and immuno...  2022
# 2     A deep learning pipeline to simulate fluorodeo...  2022
# 3     Artificial intelligence in mammographic phenot...  2022
# 4     A review on advances in 18F-FDG PET/CT radiomi...  2022
# ...                                                 ...   ...
# 9995  Systems Pharmacology-Based Precision Therapy a...  2021
# 9996  A Novel Recombinant Fcγ Receptor-Targeted Surv...  2021
# 9997  A Protective Mechanism of Visible Red Light in...  2017
# 9998  X-ray reflectivity and grazing incidence diffr...  2015
# 9999  Oroxylum indicum (L.) Kurz, an important Asian...  2015
#
#                               DOI
# 0      10.1186/s13104-022-06019-x
# 1      10.1038/s41598-022-08622-1
# 2      10.1186/s13244-022-01161-3
# 3      10.1186/s13058-022-01509-z
# 4      10.1186/s13244-021-01153-9
# ...

# %%
union_data=union2.drop_duplicates(subset='DOI', keep='first',inplace=False,ignore_index=True)
union_data
# Out:
#                                                    Title  Year  \
# 0      Radiomics combined with clinical characteristi...  2022
# 1      Characteristics of immunophenotypes and immuno...  2022
# 2      A deep learning pipeline to simulate fluorodeo...  2022
# 3      Artificial intelligence in mammographic phenot...  2022
# 4      A review on advances in 18F-FDG PET/CT radiomi...  2022
# ...                                                  ...   ...
# 10998  Systems Pharmacology-Based Precision Therapy a...  2021
# 10999  A Novel Recombinant Fcγ Receptor-Targeted Surv...  2021
# 11000  A Protective Mechanism of Visible Red Light in...  2017
# 11001  X-ray reflectivity and grazing incidence diffr...  2015
# 11002  Oroxylum indicum (L.) Kurz, an important Asian...  2015
#
#                                DOI
# 0       10.1186/s13104-022-06019-x
# 1       10.1038/s41598-022-08622-1
# 2       10.1186/s13244-022-01161-3
# 3       10.1186/s13058-022-01509-z
# ...

# %% [markdown]
# # write a review Article about the relationship between Comparative analysis of brain tumor detection using deep learning methods and Breast cancer prediction using machine learning algorithms. To do so, we restrict ourselves to the articles between 2011-2022.
#
# ##### According to the scenario, we need to filter the subjects considering cancer or the topic related to cancer(breast, prediction, machine learning algorithm, etc. (all of these are given from the expert of the field!))

# %% [markdown]
# # i picked two titles to compare they are:
# #Comparative analysis of brain tumor detection using deep learning methods and
#
# #Breast cancer prediction using machine learning algorithms

# %%
merged_PPI1=union_data.loc[(union_data['Title'].str.contains("breast")) |(union_data['Title'].str.contains("breast"))|
                           (union_data['Title'].str.contains("breast"))]
merged_PPI2=union_data.loc[(union_data['Title'].str.contains("prediction")) |(union_data['Title'].str.contains("prediction"))]
merged_PPI3=union_data.loc[(union_data['Title'].str.contains("machine learning algorithm")) |(union_data['Title'].str.contains("machine learning algorithm"))]
merged_PPI4=union_data.loc[(union_data['Title'].str.contains("cancer")) |(union_data['Title'].str.contains("cancer"))]

# %%
merged_data=merged_PPI1.append([merged_PPI2,merged_PPI3,merged_PPI4])
merged_data
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18000\3700029433.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data=merged_PPI1.append([merged_PPI2,merged_PPI3,merged_PPI4])
#                                                    Title  Year  \
# 3      Artificial intelligence in mammographic phenot...  2022
# 41     Expert system based on fuzzy rules for diagnos...  2022
# 52     Predicting the molecular subtype of breast can...  2022
# 80     Prediction of HER2 expression in breast cancer...  2022
# 82     Machine learning with multiparametric breast M...  2022
# ...                                                  ...   ...
# 10969  Phosphoproteomic analysis identifies activated...  2013
# 10975  Anticancer Effects of Salvia miltiorrhiza Alco...  2017
# 10977  Knockdown of PGM1 enhances anticancer effects ...  2021
# 10988  A(2B) adenosine receptor antagonists rescue ly...  2022
# ...

# %%
print('At the begininig we have totally {} articles:'.format(df_machinelea.shape[0]+df_scopus.shape[0]))
print('\n')
print('We have finally {} readable articles:'.format(merged_data.shape[0]))
# Out:
# At the begininig we have totally 11462 articles:
#
#
# We have finally 4354 readable articles:
